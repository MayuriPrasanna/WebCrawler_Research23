# %%
import os
import requests
import jwt
import time
import sqlite3
import json


def save_to_file(data, file_path):
    with open(file_path, 'w') as file:
        # file.write(data)
        json.dump(data, file)

def load_from_file(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def generate_jwt_token(client_id, client_secret):
    # Replace with the appropriate token endpoint URL for your OAuth server
    #token_endpoint = "https://web.arbeitsagentur.de/weiterbildungssuche/suche"
    #token_endpoint = "https://www.arbeitsagentur.de/jobsuche/suche?angebotsart=1" #Work
    token_endpoint = "https://www.arbeitsagentur.de/jobsuche/"
    now = int(time.time())
    payload = {
        "iss": client_id,
        "sub": client_id,
        "aud": token_endpoint,
        "iat": now,
        "exp": now + 3600,  # Token expires in 1 hour
    }

    # Sign the payload with your client secret to generate the JWT
    jwt_token = jwt.encode(payload, client_secret, algorithm='HS256')

    return jwt_token

def get_access_token(client_id, client_secret):
    # Generate the JWT token
    jwt_token = generate_jwt_token(client_id, client_secret)

    # Request the access token using the JWT token
    token_endpoint = "https://rest.arbeitsagentur.de/oauth/gettoken_cc"
    headers = {
        "Content-Type": "application/x-www-form-urlencoded",
    }
    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }

    response = requests.post(token_endpoint, headers=headers, data=data)

    if response.status_code == 200:
        return response.json()["access_token"]
    else:
        raise Exception(f"Failed to get access token. Status code: {response.status_code}")

def get_api_data(api_url, access_token):
    headers = {
        "Authorization": f"Bearer {access_token}",
    }

    response = requests.get(api_url, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        print(data)
        
        if data:  # Check if data is not empty
            return data
        else:
            print("No more data")
    else:
        raise Exception(f"Failed to fetch data from API. Status code: {response.status_code}")

def create_table(db_connection):
    cursor = db_connection.cursor()
    # Create a table if it doesn't exist
    cursor.execute('''CREATE TABLE IF NOT EXISTS job_offers (
    beruf TEXT NULL,
    titel TEXT NULL,
    refnr TEXT NULL,
    plz REAL NULL,
    ort TEXT NULL,
    strasse TEXT NULL,
    region TEXT NULL,    
    land TEXT NULL,
    lat REAL NULL,
    lon REAL NULL,
    arbeitgeber TEXT NULL,
    aktuelleVeroeffentlichungsdatum DATE,
    modifikationsTimestamp TIMESTAMP,
    eintrittsdatum DATE,
    logoHashId TEXT NULL,
    hashId TEXT NULL )''')
    db_connection.commit()


def insert_data_into_db(data, db_connection):
    print(len(data))
    cursor = db_connection.cursor()
    for entry in data["stellenangebote"]:
        beruf = entry.get("beruf", "")  #beruf = entry["beruf"]
        titel = entry.get("titel", "")  #entry["titel"]
        refnr = entry["refnr"]    
        arbeitgeber = entry.get("arbeitgeber", "")   #entry["arbeitgeber"]
        aktuelleVeroeffentlichungsdatum = entry["aktuelleVeroeffentlichungsdatum"]
        modifikationsTimestamp = entry["modifikationsTimestamp"]
        eintrittsdatum = entry["eintrittsdatum"]
        logoHashId = entry.get("logoHashId", "")
        hashId = entry.get("hashId", "")

        # Access the "arbeitsort" dictionary within the current job entry
        #arbeitsort = entry["arbeitsort"]
        arbeitsort = entry.get("arbeitsort", {})  # Use an empty dictionary as default
        plz = arbeitsort.get("plz")
        ort = arbeitsort.get("ort")
        strasse = arbeitsort.get("strasse")
        region = arbeitsort.get("region")
        land = arbeitsort.get("land")
        lat = arbeitsort.get("koordinaten", {}).get("lat")
        lon = arbeitsort.get("koordinaten", {}).get("lon")
        

        # Insert data into the table
        cursor.execute('''INSERT INTO job_offers (
                    beruf,
                    titel,
                    refnr,
                    plz,
                    ort,
                    strasse,   
                    region,
                    land,
                    lat,
                    lon,
                    arbeitgeber,
                    aktuelleVeroeffentlichungsdatum,
                    modifikationsTimestamp,
                    eintrittsdatum,
                    logoHashId,
                    hashId
                ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?,?)
            ''', (
                beruf,
                titel,
                refnr,
                plz,
                ort,
                strasse,
                region,
                land,
                lat,
                lon,
                arbeitgeber,
                aktuelleVeroeffentlichungsdatum,
                modifikationsTimestamp,
                eintrittsdatum,
                logoHashId,
                hashId
            ))
    db_connection.commit()
    print("insert data")


def main():
    #api_url = "https://rest.arbeitsagentur.de/infosysbub/wbsuche/pc/v1/bildungsangebot"  # Replace with the API endpoint URL
    #api_url = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/app/jobs"
    api_url = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=1"
    data_file = "data_json.txt"
    client_id = "c003a37f-024f-462a-b36d-b001be4cd24a"  # Replace with your OAuth client ID
    client_secret = "32a39620-32b3-4307-9aa1-511e3d7f48a8"  # Replace with your OAuth client secret
    #print(data_file)
    # Get the access token using client credentials flow with JWTs
    access_token = get_access_token(client_id, client_secret)
    
    try:
        # Open a connection
        db_connection = sqlite3.connect('weiterbildung_sample6.db')
        
        # Create the table if not exists
        create_table(db_connection)

        # Pagination: Fetch all data from the API using multiple requests
        all_data = []
        page = 0
        totalPages = 1
        # Inside the loop that fetches data from the API
        while page < totalPages:
            paginated_api_url = f"{api_url}"#&page={page}&size=10"
            print(paginated_api_url)
            api_data = get_api_data(paginated_api_url, access_token)
            #totalPages = api_data["page"]["totalPages"]
            # Insert data into the database
            insert_data_into_db(api_data, db_connection)  # Insert each page of data
            all_data.extend(api_data["stellenangebote"])   # Extend the all_data list
            page += 1

        # After the loop, insert all_data into the database
        insert_data_into_db(all_data, db_connection)
        print(insert_data_into_db)


    except Exception as e:
        print(f"Error: {e}")
        db_connection.rollback()  # Rollback changes in case of an error
    
    finally:
        # Close the connection
        db_connection.close()
        print("Data fetched and saved to SQLite database successfully.")


    #api_url = "https://rest.arbeitsagentur.de/infosysbub/wbsuche/pc/v1/bildungsangebot"  # Replace with the API endpoint URL
    #api_url = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/app/jobs"
    api_url2 = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=2"
    data_file = "data_json.txt"
    client_id = "c003a37f-024f-462a-b36d-b001be4cd24a"  # Replace with your OAuth client ID
    client_secret = "32a39620-32b3-4307-9aa1-511e3d7f48a8"  # Replace with your OAuth client secret
    #print(data_file)
    # Get the access token using client credentials flow with JWTs
    access_token = get_access_token(client_id, client_secret)
    
    try:
        # Open a connection
        db_connection = sqlite3.connect('weiterbildung_sample6.db')
        
        # Create the table if not exists
        create_table(db_connection)

        # Pagination: Fetch all data from the API using multiple requests
        all_data = []
        page = 0
        totalPages = 1
        # Inside the loop that fetches data from the API
        while page < totalPages:
            paginated_api_url = f"{api_url2}"#&page={page}&size=10"
            print(paginated_api_url)
            api_data = get_api_data(paginated_api_url, access_token)
            #totalPages = api_data["page"]["totalPages"]
            # Insert data into the database
            insert_data_into_db(api_data, db_connection)  # Insert each page of data
            all_data.extend(api_data["stellenangebote"])   # Extend the all_data list
            page += 1

        # After the loop, insert all_data into the database
        insert_data_into_db(all_data, db_connection)
        print(insert_data_into_db)


    except Exception as e:
        print(f"Error: {e}")
        db_connection.rollback()  # Rollback changes in case of an error
    
    finally:
        # Close the connection
        db_connection.close()
        print("Data fetched and saved to SQLite database successfully.")


    #api_url = "https://rest.arbeitsagentur.de/infosysbub/wbsuche/pc/v1/bildungsangebot"  # Replace with the API endpoint URL
    #api_url = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/app/jobs"
    api_url4 = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=4"
    data_file = "data_json.txt"
    client_id = "c003a37f-024f-462a-b36d-b001be4cd24a"  # Replace with your OAuth client ID
    client_secret = "32a39620-32b3-4307-9aa1-511e3d7f48a8"  # Replace with your OAuth client secret
    #print(data_file)
    # Get the access token using client credentials flow with JWTs
    access_token = get_access_token(client_id, client_secret)
    
    try:
        # Open a connection
        db_connection = sqlite3.connect('weiterbildung_sample6.db')
        
        # Create the table if not exists
        create_table(db_connection)

        # Pagination: Fetch all data from the API using multiple requests
        all_data = []
        page = 0
        totalPages = 1
        # Inside the loop that fetches data from the API
        while page < totalPages:
            paginated_api_url = f"{api_url4}"#&page={page}&size=10"
            print(paginated_api_url)
            api_data = get_api_data(paginated_api_url, access_token)
            #totalPages = api_data["page"]["totalPages"]
            # Insert data into the database
            insert_data_into_db(api_data, db_connection)  # Insert each page of data
            all_data.extend(api_data["stellenangebote"])   # Extend the all_data list
            page += 1

        # After the loop, insert all_data into the database
        insert_data_into_db(all_data, db_connection)
        print(insert_data_into_db)


    except Exception as e:
        print(f"Error: {e}")
        db_connection.rollback()  # Rollback changes in case of an error
    
    finally:
        # Close the connection
        db_connection.close()
        print("Data fetched and saved to SQLite database successfully.")

    #api_url = "https://rest.arbeitsagentur.de/infosysbub/wbsuche/pc/v1/bildungsangebot"  # Replace with the API endpoint URL
    #api_url = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/app/jobs"
    api_url34 = "https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=34"
    data_file = "data_json.txt"
    client_id = "c003a37f-024f-462a-b36d-b001be4cd24a"  # Replace with your OAuth client ID
    client_secret = "32a39620-32b3-4307-9aa1-511e3d7f48a8"  # Replace with your OAuth client secret
    #print(data_file)
    # Get the access token using client credentials flow with JWTs
    access_token = get_access_token(client_id, client_secret)
    
    try:
        # Open a connection
        db_connection = sqlite3.connect('weiterbildung_sample6.db')
        
        # Create the table if not exists
        create_table(db_connection)

        # Pagination: Fetch all data from the API using multiple requests
        all_data = []
        page = 0
        totalPages = 1
        # Inside the loop that fetches data from the API
        while page < totalPages:
            paginated_api_url = f"{api_url34}"#&page={page}&size=10"
            print(paginated_api_url)
            api_data = get_api_data(paginated_api_url, access_token)
            #totalPages = api_data["page"]["totalPages"]
            # Insert data into the database
            insert_data_into_db(api_data, db_connection)  # Insert each page of data
            all_data.extend(api_data["stellenangebote"])   # Extend the all_data list
            page += 1

        # After the loop, insert all_data into the database
        insert_data_into_db(all_data, db_connection)
        print(insert_data_into_db)


    except Exception as e:
        print(f"Error: {e}")
        db_connection.rollback()  # Rollback changes in case of an error
    
    finally:
        # Close the connection
        db_connection.close()
        print("Data fetched and saved to SQLite database successfully.")


if __name__ == "__main__":
    main()
# Out:
# https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=1
# {'stellenangebote': [{'beruf': 'Master of Business Administration', 'titel': 'Junior Spezialist HR Strategie - Arbeitszeit (m/w/d)', 'refnr': '11850-225621-1522481-0-S', 'arbeitsort': {'plz': '80788', 'ort': 'München', 'region': 'Bayern', 'land': 'Deutschland', 'koordinaten': {'lat': 48.1521045, 'lon': 11.5502023}}, 'arbeitgeber': 'Orizon GmbH München-Süd', 'aktuelleVeroeffentlichungsdatum': '2023-08-13', 'modifikationsTimestamp': '2023-08-11T18:00:07.596', 'eintrittsdatum': '2023-10-01', 'logoHashId': '9VLJtbiu3WLfmalceI1z_El7pkOmGL0HZn3cmF0wQPg=', 'hashId': '0Q3Jsp9XIBAXIEAiZ9llmeTbzBrAcUHEpcdUWJKWbbE='}, {'beruf': 'Betriebswirt/in (Fachschule) - Produktionswirtschaft', 'titel': 'Fertigungsplaner (m/w/d)', 'refnr': '11850-225507-1522348-0-S', 'arbeitsort': {'plz': '07745', 'ort': 'Jena', 'region': 'Thüringen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.9034275, 'lon': 11.5717884}}, 'arbeitgeber': 'Orizon GmbH NL Jena', 'aktuelleVeroeffentlichungsdatum': '2023-08-13', 'modifikationsTimestamp': '2023-08-11T12:35:42.233', 'eintrittsdatum': '2023-08-12', 'logoHashId': 'a-sZz_WvWFNsoq6X2rGycVg9uoTQLb10EFJtZ1FCw6g=', 'hashId': 'ojR8NzK9rRUFgMIvrMGCrgmgni-CBWNC1m3aCeMx18I='}, {'beruf': 'Konstrukteur/in - Elektrotechnik', 'titel': 'Ingenieur Elektrotechnik (m/w/d)', 'refnr': '11850-225505-1522345-0-S', 'arbeitsort': {'plz': '07745', 'ort': 'Jena', 'region': 'Thüringen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.9034275, 'lon': 11.5717884}}, 'arbeitgeber': 'Orizon GmbH NL Jena', 'aktuelleVeroeffentlichungsdatum': '2023-08-13', 'modifikationsTimestamp': '2023-08-11T12:35:42.521', 'eintrittsdatum': '2023-08-12', 'logoHashId': 'a-sZz_WvWFNsoq6X2rGycVg9uoTQLb10EFJtZ1FCw6g=', 'hashId': '5S5eYDS3TECEIEj83rArSZ39rNWlNyxaM-VHGfCMqKk='}, {'beruf': 'Embedded-Systems-Entwickler/in', 'titel': 'Ingenieur Elektrotechnik (m/w/d) -Elektronikentwickler FPGA (m/w/d)', 'refnr': '11850-225502-1522340-0-S', 'arbeitsort': {'plz': '07745', 'ort': 'Jena', 'region': 'Thüringen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.9034275, 'lon': 11.5717884}}, 'arbeitgeber': 'Orizon GmbH NL Jena', 'aktuelleVeroeffentlichungsdatum': '2023-08-13', 'modifikationsTimestamp': '2023-08-11T12:35:43.101', 'eintrittsdatum': '2023-08-12', 'logoHashId': 'a-sZz_WvWFNsoq6X2rGycVg9uoTQLb10EFJtZ1FCw6g=', 'hashId': '67Wv1zxdrT4--1BZX5HAHEQoHO1RC9uufQ17qvPL_wA='}, {'beruf': 'Einkäufer/in', 'titel': 'Strategischer Einkäufer zur Direktvermittlung (m/w/d)', 'refnr': '11850-225499-1522334-0-S', 'arbeitsort': {'plz': '07745', 'ort': 'Jena', 'region': 'Thüringen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.9034275, 'lon': 11.5717884}}, 'arbeitgeber': 'Orizon GmbH NL Jena', 'aktuelleVeroeffentlichungsdatum': '2023-08-13', 'modifikationsTimestamp': '2023-08-11T12:35:43.926', 'eintrittsdatum': '2023-08-12', 'logoHashId': 'a-sZz_WvWFNsoq6X2rGycVg9uoTQLb10EFJtZ1FCw6g=', 'hashId': 'esTqhTDMOdi-hPyBb4OBZURneQQhlH-S_Le-F_2Du_s='}, {'beruf': 'Betriebsinformatiker/in', 'titel': 'Projekt Regular Technician (m/w/d)', 'refnr': '11850-225376-1522229-0-S', 'arbeitsort': {'plz': '80802', 'ort': 'München', 'region': 'Bayern', 'land': 'Deutschland', 'koordinaten': {'lat': 48.1600086, 'lon': 11.5893006}}, 'arbeitgeber': 'Orizon GmbH München-Süd', 'aktuelleVeroeffentlichungsdatum': '2023-08-13', 'modifikationsTimestamp': '2023-08-10T18:10:46.522', 'eintrittsdatum': '2023-08-11', 'logoHashId': '9VLJtbiu3WLfmalceI1z_El7pkOmGL0HZn3cmF0wQPg=', 'hashId': 'Cgmuur0ZwM2h5ztP_9l2ecxNbseeStp_cLfwJ_16E2c='}, {'beruf': 'Bürokaufmann/-frau', 'titel': 'Teamassistenz im Bereich Qualität Automotive in Teilzeit (m/w/d)', 'refnr': '11850-225373-1522220-0-S', 'arbeitsort': {'plz': '80788', 'ort': 'München', 'region': 'Bayern', 'land': 'Deutschland', 'koordinaten': {'lat': 48.1521045, 'lon': 11.5502023}}, 'arbeitgeber': 'Orizon GmbH München-Süd', 'aktuelleVeroeffentlichungsdatum': '2023-08-13', 'modifikationsTimestamp': '2023-08-10T18:10:46.828', 'eintrittsdatum': '2023-08-11', 'logoHashId': '9VLJtbiu3WLf ...
# 5
# insert data
# 25
# Error: list indices must be integers or slices, not str
# Data fetched and saved to SQLite database successfully.
# https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=2
# {'stellenangebote': [{'beruf': 'Handelsvertreter/in', 'titel': 'StartUp / Gesundheit / Ernährung', 'refnr': '10000-1195521904-S', 'arbeitsort': {'ort': 'Dresden', 'region': 'Sachsen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.0665003, 'lon': 13.7726772}}, 'arbeitgeber': 'Network Wirkotsch Werner', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-12T07:21:46.642', 'eintrittsdatum': '2023-08-12', 'logoHashId': 'pvIQFoHs6F8aYyugeyqdswfTTKu4kp1_1Z7X-Powe1E=', 'hashId': 'SbmUIWmrnvOYszGHXZu4fzYmajHd16Y0Ku0ntAUNiiM='}, {'beruf': 'Lehrer/in - Deutsch als Fremdsprache', 'titel': 'Dozent (m/w/d) für BAMF-Sprachkurse (Integrationskurse und Berufssprachkurse) für ONLINE-Kurse', 'refnr': '10000-1191430918-S', 'arbeitsort': {'plz': '44793', 'ort': 'Bochum', 'strasse': 'Alleestraße 54', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.4805259, 'lon': 7.2082718}}, 'arbeitgeber': 'Milling GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-12T08:29:06.25', 'eintrittsdatum': '2023-08-15', 'logoHashId': 'gkB3-RUHcJmP86WeKpfIGpEoupVRRoGEaBsV74vKcXA=', 'hashId': '4MSzXAHmiFLbbxDAIXtWhP0su14mHGhUdHAQkOQFoW4='}, {'beruf': 'Lehrer/in - Deutsch als Fremdsprache', 'titel': 'Dozent (m/w/d) für BAMF-Sprachkurse (Integrationskurse und Berufssprachkurse) für ONLINE-Kurse', 'refnr': '10000-1191430911-S', 'arbeitsort': {'plz': '50825', 'ort': 'Köln', 'strasse': 'Venloer Straße 379', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.9504902, 'lon': 6.9160305}}, 'arbeitgeber': 'Milling GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-12T08:30:30.776', 'eintrittsdatum': '2023-08-15', 'logoHashId': 'gkB3-RUHcJmP86WeKpfIGpEoupVRRoGEaBsV74vKcXA=', 'hashId': 'BctVkiiM4jV_-VEwTnWkTZ1yA0eP1MLlGeLmSRfdRHE='}, {'beruf': 'Lehrer/in - Deutsch als Fremdsprache', 'titel': 'Dozent (m/w/d) für BAMF-Sprachkurse (Integrationskurse)', 'refnr': '10000-1191430531-S', 'arbeitsort': {'plz': '57489', 'ort': 'Drolshagen', 'strasse': 'Annostraße 3', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.0239513, 'lon': 7.7780406}}, 'arbeitgeber': 'Milling GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-12T08:18:48.584', 'eintrittsdatum': '2023-08-15', 'logoHashId': 'gkB3-RUHcJmP86WeKpfIGpEoupVRRoGEaBsV74vKcXA=', 'hashId': 'n6jCCzpSwRadfBfEnXpqJa-LLe8a2rQinFyyDrBsqJs='}, {'beruf': 'Lehrer/in - Deutsch als Fremdsprache', 'titel': 'Dozent (m/w/d) für BAMF-Sprachkurse (Integrationskurse)', 'refnr': '10000-1189554801-S', 'arbeitsort': {'plz': '56269', 'ort': 'Dierdorf', 'strasse': 'Königsberger Straße 17', 'region': 'Rheinland-Pfalz', 'land': 'Deutschland', 'koordinaten': {'lat': 50.5467678, 'lon': 7.6395528}}, 'arbeitgeber': 'Milling GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-12T08:31:42.067', 'eintrittsdatum': '2023-08-15', 'logoHashId': 'gkB3-RUHcJmP86WeKpfIGpEoupVRRoGEaBsV74vKcXA=', 'hashId': 'yOQxV1Sua_21cbGh4MqBgzKgckp9la832F9bVNBZ4Ug='}, {'beruf': 'Lehrer/in - Deutsch als Fremdsprache', 'titel': 'Dozent (m/w/d) für BAMF-Sprachkurse (Integrationskurse)', 'refnr': '10000-1189554799-S', 'arbeitsort': {'plz': '53894', 'ort': 'Mechernich', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.5938498, 'lon': 6.6504542}}, 'arbeitgeber': 'Milling GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-12T08:20:36.392', 'eintrittsdatum': '2023-08-15', 'logoHashId': 'gkB3-RUHcJmP86WeKpfIGpEoupVRRoGEaBsV74vKcXA=', 'hashId': 'q49yxPrdkQxyuSzTslvW35d2yFZ_wwzl3THxVjVBB1E='}, {'beruf': 'Lehrer/in - Deutsch als Fremdsprache', 'titel': 'Dozent (m/w/d) für BAMF-Sprachkurse (Integrationskurse)', 'refnr': '10000-1189554797-S', 'arbeitsort': {'plz': '56457', 'ort': 'Westerburg, Westerwald', 'strasse': 'Adolfstraße 3', 'region': 'Rheinland- ...
# 5
# insert data
# 25
# Error: list indices must be integers or slices, not str
# Data fetched and saved to SQLite database successfully.
# https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=4
# {'stellenangebote': [{'beruf': 'Kaufmann/-frau - Dialogmarketing', 'titel': 'Ausbildung zum Kaufmann für Dialogmarketing (m/w/d)', 'refnr': '17391-0034277234-S', 'arbeitsort': {'plz': '34117', 'ort': 'Kassel, Hessen', 'region': 'Hessen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.3160344, 'lon': 9.4919156}}, 'arbeitgeber': 'KVV Kasseler Verkehrs- und Versorgungs- GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-08T08:49:01.611', 'eintrittsdatum': '2024-08-01', 'hashId': 'OAXBPORjQaOCTGaeO7KUhqRDq8uWIsJNwlz-fm24Y1w='}, {'beruf': 'Produktionsfachkraft Chemie', 'titel': 'Ausbildung Produktionsfachkraft Chemie (m/w/d)', 'refnr': '16852-41803422-811-S', 'arbeitsort': {'plz': '49448', 'ort': 'Lemförde', 'strasse': 'Elastogranstraße 60', 'region': 'Niedersachsen', 'land': 'Deutschland', 'koordinaten': {'lat': 52.4594304, 'lon': 8.385015}}, 'arbeitgeber': 'BASF Services Europe GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T15:52:55.085', 'eintrittsdatum': '2024-07-31', 'logoHashId': '4urc00H6hmKV6bHHsTvffILO8btkDv3kDEYFqjeQbc0=', 'hashId': 'wrGQMQVhpdBXCU5c7tgtko0ydG8M7xrobZl0WZdrHOg='}, {'beruf': 'Kaufmann/-frau - Büromanagement', 'titel': 'Ausbildung Kaufmann:frau für Büromanagement (m/w/d)', 'refnr': '16852-41802779-811-S', 'arbeitsort': {'plz': '49448', 'ort': 'Lemförde', 'strasse': 'Elastogranstraße 60', 'region': 'Niedersachsen', 'land': 'Deutschland', 'koordinaten': {'lat': 52.4594304, 'lon': 8.385015}}, 'arbeitgeber': 'BASF Services Europe GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T13:24:32.23', 'eintrittsdatum': '2024-08-01', 'logoHashId': '4urc00H6hmKV6bHHsTvffILO8btkDv3kDEYFqjeQbc0=', 'hashId': 'eg_oH2JSKcAaq191wJr3BtXyDNbt2O2sYfDdwnNInY8='}, {'beruf': 'Mechatroniker/in', 'titel': 'Ausbildung zum*zur Mechatroniker*in', 'refnr': '15861-41802827-811-S', 'arbeitsort': {'plz': '85354', 'ort': 'Freising, Oberbayern', 'region': 'Bayern', 'land': 'Deutschland', 'koordinaten': {'lat': 48.3927994, 'lon': 11.7036783}}, 'arbeitgeber': 'Zentrale der Fraunhofer Gesellschaft e.V.', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T12:54:01.282', 'eintrittsdatum': '2024-09-01', 'logoHashId': '6qz7moZwZr4UNYLKpp67bgHo4pPF7JTr8zi1Pdav47A=', 'hashId': 'gd03oki5i0lsYGWpQHTC5e2NdiQDAqBpCRa3QPDarxE='}, {'beruf': 'Diätassistent/in', 'titel': 'Ausbildung zur Diätassistentin / zum Diätassistenten (m/w/d), Beginn 01.09.2024', 'refnr': '13916-41802056-811-S', 'arbeitsort': {'plz': '33611', 'ort': 'Bielefeld', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 52.0492335, 'lon': 8.5469242}}, 'arbeitgeber': 'v. Bodelschwinghsche Stiftungen Bethel Bewerbermanagement', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T14:13:17.654', 'eintrittsdatum': '2024-09-01', 'logoHashId': 'mpNW0HXzLzqMRguw1gQc6Mi8eIjp0IJ8NTQPgAAVso4=', 'hashId': 'idnubESE0KFbAgNssrWNvLZbNhracBHNW5M22Us-iVE='}, {'beruf': 'Industriekaufmann/-frau', 'titel': 'Ausbildung Industriekaufmann* 2024', 'refnr': '12743-41803359-811-S', 'arbeitsort': {'plz': '36037', 'ort': 'Fulda', 'region': 'Hessen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.5565193, 'lon': 9.6857423}}, 'arbeitgeber': 'EDAG Engineering GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T15:22:00.026', 'eintrittsdatum': '2024-08-31', 'logoHashId': 'PG4CZcEVCs1AQCqdbX9qpNB33gBuQMAuRcl5Bs_-Qw4=', 'hashId': 'm0G9lySix0fVXAB18Gn_-9XzikskgmPUkYsCdf4Y_Os='}, {'titel': 'Duales Studium Wirtschaftsingenieurwesen International Maschinenbau - Produktion und Logistik 2024', 'refnr': '12743-41802665-811-S', 'arbeitsort': {'plz': '36037', 'ort': 'Fulda', 'region': 'Hessen', 'land': 'Deutschland', 'koordinaten': {'lat': 50.5565193, 'lon': 9.6857423}}, 'arbeitgeber': 'EDAG Engineering GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifika ...
# 5
# insert data
# 25
# Error: list indices must be integers or slices, not str
# Data fetched and saved to SQLite database successfully.
# https://rest.arbeitsagentur.de/jobboerse/jobsuche-service/pc/v4/jobs?angebotsart=34
# {'stellenangebote': [{'beruf': 'Marketingfachkraft/-assistent/in', 'titel': 'Praktikum Customer Marketing (m/w/d)', 'refnr': '15224-41803381-811-S', 'arbeitsort': {'plz': '80802', 'ort': 'München', 'region': 'Bayern', 'land': 'Deutschland', 'koordinaten': {'lat': 48.1600086, 'lon': 11.5893006}}, 'arbeitgeber': 'ProSiebenSat.1 Media SE', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T15:22:00.315', 'eintrittsdatum': '2023-09-14', 'logoHashId': 'DYgwjbdjs3cC8rr3vD0lqrz4faoBQc3IXniHxuY7m_g=', 'hashId': '_l0rWqAmM7HKymhpgYxAdwleUIjf_Kv3KdTQsEyi1ZQ='}, {'beruf': 'Ingenieur/in - Energietechnik', 'titel': 'Werkstudent (m/w/d) Netzbetrieb', 'refnr': '15139-41802574-811-S', 'arbeitsort': {'plz': '46483', 'ort': 'Wesel am Rhein', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.6636068, 'lon': 6.612518}}, 'arbeitgeber': 'Westenergie AG Zentrale', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T11:51:50.65', 'eintrittsdatum': '2023-08-12', 'logoHashId': 'WMsr0oI8rePE3Uik40ataQXlf7ByFFQyAT8uSurX5hY=', 'hashId': 'kpr1Jocj835ZuygJn9p8iUfPsJOzJxPRq-Ys2c7aGxo='}, {'beruf': 'Steuerberater/in', 'titel': 'Werkstudent Transfer Pricing / Verrechnungspreise (m/w/d)', 'refnr': '14978-41803144-811-S', 'arbeitsort': {'plz': '48155', 'ort': 'Münster, Westfalen', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.9483554, 'lon': 7.6766233}}, 'arbeitgeber': 'Rödl GmbH RAG StBG', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T14:22:56.56', 'eintrittsdatum': '2023-08-12', 'logoHashId': 'XU5txpfCOoeS5NbBYQr0dQuqk-KtBnAF2wwrKXG8Xj8=', 'hashId': 'ue_gnpQo7989K_YNl24GmZ3pWURwwLRJNQjkFDuKjbE='}, {'beruf': 'Assistent/in - Pressestelle', 'titel': 'Praktikum im Bereich Presse Blantvalet', 'refnr': '13660-41802096-811-S', 'arbeitsort': {'plz': '81673', 'ort': 'München', 'region': 'Bayern', 'land': 'Deutschland', 'koordinaten': {'lat': 48.126177, 'lon': 11.6299464}}, 'arbeitgeber': 'Penguin Random House Verlagsgruppe GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T09:52:53.618', 'eintrittsdatum': '2023-09-14', 'logoHashId': '9AKC0v5qBCt3ZwwrXzn3g1HhtnHedMnhQ7yXX-VwZqg=', 'hashId': '2Tsrh09VMx3bO8X5cFFnrD8-VWvJzxHATll72BeI0KA='}, {'beruf': 'Fachkraft - Arbeitssicherheit', 'titel': 'Werkstudent Arbeitssicherheit/IT', 'refnr': '12876-41796985-89-S', 'arbeitsort': {'plz': '97959', 'ort': 'Assamstadt', 'strasse': 'Industriestraße 3', 'region': 'Baden-Württemberg', 'land': 'Deutschland', 'koordinaten': {'lat': 49.4272293, 'lon': 9.6998684}}, 'arbeitgeber': 'Magna International', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T10:21:05.974', 'eintrittsdatum': '2023-08-11', 'logoHashId': 'mNakd0X5OF7XpPJ8jjjX8O2p1fTWnE_TiUf8cI7nFX0=', 'hashId': 'u7oUiSCyqSEMeYUzDA8AAaPmJKvFfa8YpXL26oWHyO4='}, {'beruf': 'Ingenieur/in - Energietechnik', 'titel': 'Pflichtpraktikant / Werkstudent Energiesystemplanung (m/w/d)', 'refnr': '12706-41803727-811-S', 'arbeitsort': {'plz': '44263', 'ort': 'Dortmund', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.487561, 'lon': 7.4987586}}, 'arbeitgeber': 'Amprion GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T18:00:11.336', 'eintrittsdatum': '2023-08-12', 'logoHashId': '1_HbMXIRff6RfsxXaDqu2JUk4yn471Yl8ZJLQ6OeH_E=', 'hashId': '7Qt15Qelr-CP4qU6dqK1dGCjOhkyZs6i6_R8Y07EDzc='}, {'beruf': 'Betriebswirt/in (Hochschule) - Werbung, Marketingkommunik.', 'titel': 'Werkstudent Unternehmenskommunikation (m/w/d)', 'refnr': '12706-41764150-727-S', 'arbeitsort': {'plz': '44263', 'ort': 'Dortmund', 'region': 'Nordrhein-Westfalen', 'land': 'Deutschland', 'koordinaten': {'lat': 51.487561, 'lon': 7.4987586}}, 'arbeitgeber': 'Amprion GmbH', 'aktuelleVeroeffentlichungsdatum': '2023-08-12', 'modifikationsTimestamp': '2023-08-11T12 ...
# 5
# insert data
# 25
# Error: list indices must be integers or slices, not str
# Data fetched and saved to SQLite database successfully.
