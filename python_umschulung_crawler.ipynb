# %%
import os
import requests
import jwt
import time
import sqlite3
import json

def save_to_file(data, file_path):
    with open(file_path, 'w') as file:
        # file.write(data)
        json.dump(data, file)

def load_from_file(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def generate_jwt_token(client_id, client_secret):
    # Replace with the appropriate token endpoint URL for your OAuth server
    token_endpoint = "https://web.arbeitsagentur.de/ausbildungssuche/berufsausbildung-suche?sty=0&seite={}&atyp=102&kat=1"

    now = int(time.time())
    payload = {
        "iss": client_id,
        "sub": client_id,
        "aud": token_endpoint,
        "iat": now,
        "exp": now + 3600,  # Token expires in 1 hour
    }

    # Sign the payload with your client secret to generate the JWT
    jwt_token = jwt.encode(payload, client_secret, algorithm='HS256')

    return jwt_token

def get_access_token(client_id, client_secret):
    # Generate the JWT token
    jwt_token = generate_jwt_token(client_id, client_secret)

    # Request the access token using the JWT token
    token_endpoint = "https://rest.arbeitsagentur.de/oauth/gettoken_cc"
    headers = {
        "Content-Type": "application/x-www-form-urlencoded",
    }
    data = {
        "grant_type": "client_credentials",
        "client_id": client_id,
        "client_secret": client_secret
    }

    response = requests.post(token_endpoint, headers=headers, data=data)

    if response.status_code == 200:
        return response.json()["access_token"]
    else:
        raise Exception(f"Failed to get access token. Status code: {response.status_code}")

def get_api_data(api_url, access_token):
    headers = {
        "Authorization": f"Bearer {access_token}",
    }

    response = requests.get(api_url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        if data:  # Check if data is not empty
            return data
        else:
            print("No more data")
    else:
        raise Exception(f"Failed to fetch data from API. Status code: {response.status_code}")

def create_table(db_connection):
    cursor = db_connection.cursor()
    # Create a table if it doesn't exist
    cursor.execute('''CREATE TABLE IF NOT EXISTS umschulung_data
                            (
                                event_id INTEGER PRIMARY KEY,
                                title TEXT NULL,
                                degree_type TEXT NULL,
                                degree_designation TEXT NULL,event_link TEXT NULL,
                                duration TEXT NULL,
                                min_participants INTEGER NULL,
                                max_participants INTEGER NULL,
                                form_of_teaching TEXT NULL,
                                cost_remark TEXT NULL,
                                financial_support TEXT NULL,
                                education_type TEXT NULL,
                                begin TEXT NULL,
                                end TEXT NULL,
                                examining_body TEXT NULL,
                                lesson_timings TEXT NULL,
                                currency TEXT NULL,
                                individual_entry BOOLEAN NULL,
                                type_of_school TEXT NULL,
                                provider_id INTEGER NULL,
                                provider_name TEXT NULL,
                                provider_homepage TEXT NULL,
                                provider_email TEXT NULL,
                                provider_address_id INTEGER NULL,
                                provider_add_name TEXT NULL,
                                provider_address_street TEXT NULL,
                                provider_ort_plz INTEGER NULL,
                                provider_ort_name TEXT NULL,
                                provider_lat DOUBLE NULL,
                                provider_lon DOUBLE NULL,
                                address_id INTEGER NULL,
                                address_name TEXT NULL,
                                training_street TEXT NULL,
                                t_ort_plz INTEGER NULL,
                                t_ort_name TEXT NULL,
                                training_lat DOUBLE NULL,
                                training_lon DOUBLE NULL,
                                update_time INTEGER NULL
                            )
                ''')
    db_connection.commit()

# %%
def insert_data_into_db(data, db_connection):
    cursor = db_connection.cursor()
    for entry in data:
        id = entry["id"]
        teilnehmerMin = entry["teilnehmerMin"]
        unterrichtsform = entry["unterrichtsform"]
        pruefendeStelle = entry["pruefendeStelle"]
        unterrichtszeiten = entry["unterrichtszeiten"]
        teilnehmerMax = entry["teilnehmerMax"] 
        kostenBemerkung = entry["kostenBemerkung"]
        beginn = entry["beginn"]
        ende = entry["ende"]
        kostenWaehrung = entry["kostenWaehrung"]
        individuellerEinstieg = entry["individuellerEinstieg"] 
        aktualisierungsdatum = entry["aktualisierungsdatum"]
        dauer = entry["dauer"]
        angebot = entry["angebot"]
        adresse = entry["adresse"]
        koordinatenP = entry["angebot"]["bildungsanbieter"]['adresse']['ortStrasse']['koordinatenPlz']
        
        if(adresse != None):
            cursor.execute('''INSERT INTO umschulung_data (
                    event_id,title, degree_type, degree_designation, 
                    event_link, duration, min_participants, max_participants, form_of_teaching, cost_remark, financial_support, education_type,
                    begin, end,examining_body, lesson_timings, currency, individual_entry, 
                    type_of_school, 
                    provider_id,
                    provider_name, provider_homepage, provider_email,
                    provider_address_id, provider_add_name,
                    provider_address_street,
                    provider_ort_plz, provider_ort_name,
                    provider_lat,
                    provider_lon,
                    address_id, address_name,
                    training_street, t_ort_plz, t_ort_name, training_lat, training_lon, update_time

                ) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?,
                         ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?
                )
            ''',(
                    id, angebot["titel"], angebot["abschlussart"], angebot["abschlussbezeichnung"], angebot["link"], dauer["bezeichnung"], teilnehmerMin, teilnehmerMax,
                    unterrichtsform["bezeichnung"], kostenBemerkung, angebot["foerderung"], angebot["bildungsart"]["bezeichnung"], beginn, ende,
                    pruefendeStelle, unterrichtszeiten, kostenWaehrung, individuellerEinstieg,
                    angebot["schulart"]["bezeichnung"], angebot["bildungsanbieter"]["id"], angebot["bildungsanbieter"]["name"], angebot["bildungsanbieter"]["homepage"],
                    angebot["bildungsanbieter"]["email"], angebot["bildungsanbieter"]["adresse"]["id"], angebot["bildungsanbieter"]["adresse"]["bezeichnung"],
                    angebot["bildungsanbieter"]["adresse"]["strasse"], angebot["bildungsanbieter"]["adresse"]["ortStrasse"]["plz"], angebot["bildungsanbieter"]["adresse"]["ortStrasse"]["name"],
                    koordinatenP["lat"], koordinatenP["lon"], 
                    adresse["id"], adresse["bezeichnung"],
                    adresse["strasse"], adresse["ortStrasse"]["plz"], adresse["ortStrasse"]["name"], adresse["ortStrasse"]["koordinatenPlz"]["lat"],
                    adresse["ortStrasse"]["koordinatenPlz"]["lon"], aktualisierungsdatum
                )
            )
        
        
    db_connection.commit()
    print("insert data")

# %%
def main():
    api_url = " https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot"  # Replace with the API endpoint URL
    data_file = "data_json.txt"
    client_id = "1c852184-1944-4a9e-a093-5cc078981294"  # Replace with your OAuth client ID
    client_secret = "777f9915-9f0d-4982-9c33-07b5810a3e79"  # Replace with your OAuth client secret

    # Get the access token using client credentials flow with JWTs
    access_token = get_access_token(client_id, client_secret)

    try:
        # Open a connection
        db_connection = sqlite3.connect('weiterbildung_analysis.db')
        
        # Create the table if not exists
        create_table(db_connection)

        # Pagination: Fetch all data from the API using multiple requests
        all_data = []
        page = 0
        totalPages = 2
        while page < totalPages:
            paginated_api_url = f"{api_url}?page={page}&size=20"
            print(paginated_api_url)
            api_data = get_api_data(paginated_api_url, access_token)
            totalPages = api_data["page"]["totalPages"]
            # save_to_file(api_data, data_file)
            # Insert data into the database
            insert_data_into_db(list(api_data["_embedded"]["termine"]), db_connection)
            # all_data.extend(api_data["_embedded"]["termine"])
            page += 1
        
        
        
        # # Insert data into the database
        # insert_data_into_db(all_data, db_connection)

    except Exception as e:
        print(f"Error: {e}")
        db_connection.rollback()  # Rollback changes in case of an error
    
    finally:
        # Close the connection
        db_connection.close()
        print("Data fetched and saved to SQLite database successfully.")


if __name__ == "__main__":
    main()
# Out:
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=0&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=1&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=2&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=3&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=4&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=5&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=6&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=7&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=8&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=9&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=10&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=11&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=12&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=13&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=14&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=15&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=16&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=17&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=18&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=19&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=20&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=21&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=22&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=23&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=24&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=25&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=26&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=27&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=28&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=29&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=30&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=31&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=32&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=33&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=34&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=35&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=36&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=37&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=38&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=39&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=40&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=41&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=42&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=43&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=44&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=45&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=46&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=47&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=48&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=49&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=50&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=51&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=52&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=53&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=54&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=55&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=56&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=57&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=58&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=59&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=60&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=61&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=62&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=63&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=64&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=65&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=66&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=67&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=68&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=69&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=70&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=71&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=72&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=73&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=74&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=75&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=76&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=77&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=78&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=79&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=80&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=81&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=82&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=83&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=84&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=85&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=86&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=87&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=88&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=89&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=90&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=91&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=92&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=93&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=94&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=95&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=96&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=97&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=98&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=99&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=100&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=101&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=102&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=103&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=104&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=105&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=106&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=107&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=108&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=109&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=110&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=111&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=112&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=113&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=114&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=115&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=116&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=117&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=118&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=119&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=120&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=121&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=122&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=123&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=124&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=125&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=126&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=127&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=128&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=129&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=130&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=131&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=132&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=133&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=134&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=135&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=136&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=137&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=138&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=139&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=140&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=141&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=142&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=143&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=144&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=145&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=146&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=147&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=148&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=149&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=150&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=151&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=152&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=153&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=154&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=155&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=156&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=157&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=158&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=159&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=160&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=161&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=162&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=163&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=164&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=165&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=166&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=167&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=168&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=169&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=170&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=171&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=172&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=173&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page=174&size=20
# insert data
#  https://rest.arbeitsagentur.de/infosysbub/absuche/pc/v1/ausbildungsangebot?page